# %% [markdown]
# # 背景：使用基于卷积的深度神经网络 ResNet50 对 30 种水果进行分类

# %% [markdown]
# ## 1、划分训练集和验证集

# %%
import os
import shutil
import random
import pandas as pd

# %%
# 指定数据集路径
dataset_path = '../data'

# %%
dataset_name = dataset_path.split('_')[0]
print('数据集', dataset_name)
# Out:
# 数据集 ../data

# %%
classes = os.listdir(dataset_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_161237/1221028200.py in <module>
# ----> 1 classes = os.listdir(dataset_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data'

# %%
len(classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_161237/1963287787.py in <module>
# ----> 1 len(classes)
#
# NameError: name 'classes' is not defined

# %%
classes
# Out:
# ['石榴',
#  '菠萝',
#  '柠檬',
#  '西瓜',
#  '砂糖橘',
#  '猕猴桃',
#  '香蕉',
#  '苦瓜',
#  '哈密瓜',
#  '荔枝',
#  '榴莲',
#  '西红柿',
#  '脐橙',
#  '山竹',
#  '芒果',
#  '火龙果',
#  '桂圆',
#  '胡萝卜',
#  '柚子',
#  '杨梅',
#  '苹果-红',
#  '黄瓜',
#  '梨',
#  '葡萄-红',
#  '椰子',
#  '车厘子',
#  '葡萄-白',
#  '苹果-青',
#  '圣女果',
#  '草莓']

# %%
# 创建 train 文件夹
os.mkdir(os.path.join(dataset_path, 'train'))

# 创建 val 文件夹
os.mkdir(os.path.join(dataset_path, 'val'))

# 在 train 和 test 文件夹中创建各类别子文件夹
for fruit in classes:
    os.mkdir(os.path.join(dataset_path, 'train', fruit))
    os.mkdir(os.path.join(dataset_path, 'val', fruit))

# %%
test_frac = 0.2  # 验证集比例
random.seed(123) # 随机数种子，便于复现

# %%
# 划分训练集、验证集，移动文件
df = pd.DataFrame()

print('{:^18} {:^18} {:^18}'.format('类别', '训练集数据个数', '测试集数据个数'))

for fruit in classes: # 遍历每个类别

    # 读取该类别的所有图像文件名
    old_dir = os.path.join(dataset_path, fruit)
    images_filename = os.listdir(old_dir)
    random.shuffle(images_filename) # 随机打乱

    # 划分训练集和测试集
    testset_numer = int(len(images_filename) * test_frac) # 测试集图像个数
    testset_images = images_filename[:testset_numer]      # 获取拟移动至 test 目录的测试集图像文件名
    trainset_images = images_filename[testset_numer:]     # 获取拟移动至 train 目录的训练集图像文件名

    # 移动图像至 test 目录
    for image in testset_images:
        old_img_path = os.path.join(dataset_path, fruit, image)         # 获取原始文件路径
        new_test_path = os.path.join(dataset_path, 'val', fruit, image) # 获取 test 目录的新文件路径
        shutil.move(old_img_path, new_test_path) # 移动文件

    # 移动图像至 train 目录
    for image in trainset_images:
        old_img_path = os.path.join(dataset_path, fruit, image)           # 获取原始文件路径
        new_train_path = os.path.join(dataset_path, 'train', fruit, image) # 获取 train 目录的新文件路径
        shutil.move(old_img_path, new_train_path) # 移动文件
    
    # 删除旧文件夹
    assert len(os.listdir(old_dir)) == 0 # 确保旧文件夹中的所有图像都被移动走
    shutil.rmtree(old_dir) # 删除文件夹
    
    # 工整地输出每一类别的数据个数
    print('{:^18} {:^18} {:^18}'.format(fruit, len(trainset_images), len(testset_images)))
    
    # 保存到表格中
    df = df.append({'class':fruit, 'trainset':len(trainset_images), 'testset':len(testset_images)}, ignore_index=True)
# 重命名数据集文件夹
shutil.move(dataset_path, dataset_name+'_split')

# 数据集各类别数量统计表格，导出为 csv 文件
df['total'] = df['trainset'] + df['testset']
df.to_csv('数据量统计.csv', index=False)
# Out:
#         类别              训练集数据个数            测试集数据个数
#         石榴                120                 30
#         菠萝                122                 30
#         柠檬                 96                 23
#         西瓜                120                 29
#        砂糖橘                114                 28
#        猕猴桃                120                 30
#         香蕉                116                 29
#         苦瓜                116                 28
#        哈密瓜                121                 30
#         荔枝                125                 31
#         榴莲                119                 29
#        西红柿                119                 29
#         脐橙                121                 30
#         山竹                115                 28
#         芒果                106                 26
#        火龙果                117                 29
#         桂圆                123                 30
#        胡萝卜                117                 29
#         柚子                119                 29
#         杨梅                120                 29
#        苹果-红               114                 28
#         黄瓜                112                 28
#         梨                 121                 30
#        葡萄-红               125                 31
#         椰子                124                 30
#        车厘子                104                 25
#        葡萄-白               100                 24
#        苹果-青               121                 30
#        圣女果                123                 30
#         草莓                123                 30

# %%
df
# Out:
#    class  trainset  testset  total
# 0     石榴     120.0     30.0  150.0
# 1     菠萝     122.0     30.0  152.0
# 2     柠檬      96.0     23.0  119.0
# 3     西瓜     120.0     29.0  149.0
# 4    砂糖橘     114.0     28.0  142.0
# 5    猕猴桃     120.0     30.0  150.0
# 6     香蕉     116.0     29.0  145.0
# 7     苦瓜     116.0     28.0  144.0
# 8    哈密瓜     121.0     30.0  151.0
# 9     荔枝     125.0     31.0  156.0
# 10    榴莲     119.0     29.0  148.0
# 11   西红柿     119.0     29.0  148.0
# 12    脐橙     121.0     30.0  151.0
# 13    山竹     115.0     28.0  143.0
# 14    芒果     106.0     26.0  132.0
# 15   火龙果     117.0     29.0  146.0
# 16    桂圆     123.0     30.0  153.0
# 17   胡萝卜     117.0     29.0  146.0
# 18    柚子     119.0     29.0  148.0
# 19    杨梅     120.0     29.0  149.0
# 20  苹果-红     114.0     28.0  142.0
# 21    黄瓜     112.0     28.0  140.0
# 22     梨     121.0     30.0  151.0
# 23  葡萄-红     125.0     31.0  156.0
# 24    椰子     124.0     30.0  154.0
# 25   车厘子     104.0     25.0  129.0
# 26  葡萄-白     100.0     24.0  124.0
# 27  苹果-青     121.0     30.0  151.0
# 28   圣女果     123.0     30.0  153.0
# 29    草莓     123.0     30.0  153.0

# %% [markdown]
# ## 2、按照 MMPreTrain CustomDataset 格式组织训练集和验证集
# ## 3、在水果数据集上进行微调训练
# ## 4、使用 MMPreTrain 算法库，编写配置文件，正确加载预训练模型

# %%
# !apt update
# !apt install wget

# %%
# !wget https://download.openmmlab.com/mmclassification/v0/resnet/resnetv1d50_b32x8_imagenet_20210531-db14775a.pth
# Out:
# --2023-06-10 12:29:44--  https://download.openmmlab.com/mmclassification/v0/resnet/resnetv1d50_b32x8_imagenet_20210531-db14775a.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 64:ff9b::8001:9dd3, 64:ff9b::8001:9dd2, 64:ff9b::8001:9dd6, ...
# Connecting to download.openmmlab.com (download.openmmlab.com)|64:ff9b::8001:9dd3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102670363 (98M) [application/octet-stream]
# Saving to: 'resnetv1d50_b32x8_imagenet_20210531-db14775a.pth'
#
# resnetv1d50_b32x8_i 100%[===================>]  97.91M  2.11MB/s    in 94s
#
# 2023-06-10 12:31:21 (1.04 MB/s) - 'resnetv1d50_b32x8_imagenet_20210531-db14775a.pth' saved [102670363/102670363]

# %%
from mmengine import Config
# /mmpretrain/configs/resnet/resnet50_8xb32_in1k.py
baseline_cfg_path = '../configs/resnet/resnet50_8xb32_in1k.py'
# /mmsegmentation/configs/mask2former/mask2former_swin-s_8xb2-160k_xuchen-512x512.py
cfg = Config.fromfile(baseline_cfg_path)
model_name = baseline_cfg_path.split("/")[-1].split(".")[0]
print(f"config base model of :{model_name} ")
# Out:
# config base model of :resnet50_8xb32_in1k

# %%
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch'),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=1000,
#         in_channels=2048,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#         topk=(1, 5)))
# dataset_type = 'ImageNet'
# data_preprocessor = dict(
#     num_classes=1000,
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='RandomResizedCrop', scale=224),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='ResizeEdge', scale=256, edge='short'),
#     dict(type='CenterCrop', crop_size=224),
#     dict(type='PackInputs')
# ]
# train_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='ImageNet',
#         data_root='data/imagenet',
#         ann_file='meta/train.txt',
#         data_prefix='train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='ImageNet',
#         data_root='data/imagenet',
#         ann_file='meta/val.txt',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=(1, 5))
# test_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='ImageNet',
#         data_root='data/imagenet',
#         ann_file='meta/val.txt',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_evaluator = dict(type='Accuracy', topk=(1, 5))
# optim_wrapper = dict(
#     optimizer=dict(type='SGD', lr=0.1, momentum=0.9, weight_decay=0.0001))
# param_scheduler = dict(
#     type='MultiStepLR', by_epoch=True, milestones=[30, 60, 90], gamma=0.1)
# train_cfg = dict(by_epoch=True, max_epochs=100, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=256)
# default_scope = 'mmpretrain'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='UniversalVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = None
# resume = False
# randomness = dict(seed=None, deterministic=False)

# %%
cfg.model.head.num_classes=30
cfg.data_preprocessor.num_classes=30
cfg.train_dataloader.dataset=dict(
        type='CustomDataset',
        data_root='../data_split',
        data_prefix='train',
        pipeline=[
            dict(type='LoadImageFromFile'),
            dict(type='RandomResizedCrop', scale=224),
            dict(type='RandomFlip', prob=0.5, direction='horizontal'),
            dict(type='PackInputs')
        ])


cfg.val_dataloader.dataset=dict(
        type='CustomDataset',
        data_root='../data_split',
        data_prefix='val',
        pipeline=[
            dict(type='LoadImageFromFile'),
            dict(type='ResizeEdge', scale=256, edge='short'),
            dict(type='CenterCrop', crop_size=224),
            dict(type='PackInputs')
        ])

cfg.test_dataloader.dataset=dict(
        type='CustomDataset',
        data_root='../data_split',
        data_prefix='val',
            pipeline=[
            dict(type='LoadImageFromFile'),
            dict(type='ResizeEdge', scale=256, edge='short'),
            dict(type='CenterCrop', crop_size=224),
            dict(type='PackInputs')
        ])
cfg.default_hooks = dict(
    timer=dict(type='IterTimerHook'),
    logger=dict(type='LoggerHook', interval=100),
    param_scheduler=dict(type='ParamSchedulerHook'),
    checkpoint=dict(type='CheckpointHook', interval=50,save_best='auto',),
    sampler_seed=dict(type='DistSamplerSeedHook'),
    visualization=dict(type='VisualizationHook', enable=False))


cfg.work_dir ="ImageClassifier"

# %%
if_train = True
from mmengine.runner import Runner
if if_train:
    runner = Runner.from_cfg(cfg)
# Out:
# 06/10 12:41:09 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.13 (default, Mar 29 2022, 02:18:16) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 1254481904
#     GPU 0: NVIDIA GeForce RTX 3060
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.12.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.1
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1254481904
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/10 12:41:09 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch'),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=30,
#         in_channels=2048,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#         topk=(1, 5)))
# dataset_type = 'ImageNet'
# data_preprocessor = dict(
#     num_classes=30,
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='RandomResizedCrop', scale=224),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='ResizeEdge', scale=256, edge='short'),
#     dict(type='CenterCrop', crop_size=224),
#     dict(type='PackInputs')
# ]
# train_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='../data_split',
#         data_prefix='train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='../data_split',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=(1, 5))
# test_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='../data_split',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_evaluator = dict(type='Accuracy', topk=(1, 5))
# optim_wrapper = dict(
#     optimizer=dict(type='SGD', lr=0.1, momentum=0.9, weight_decay=0.0001))
# param_scheduler = dict(
#     type='MultiStepLR', by_epoch=True, milestones=[30, 60, 90], gamma=0.1)
# train_cfg = dict(by_epoch=True, max_epochs=100, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=256)
# default_scope = 'mmpretrain'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=50, save_best='auto'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='UniversalVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = None
# resume = False
# randomness = dict(seed=None, deterministic=False)
# work_dir = 'ImageClassifier'
#
# 06/10 12:41:09 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/10 12:41:09 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %%
# start training
if if_train:
 runner.train()
# Out:
# 06/10 12:41:09 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/10 12:41:09 - mmengine - INFO - Checkpoints will be saved to /mmpretrain/xuchenworkspace/ImageClassifier.
# 06/10 12:41:30 - mmengine - INFO - Epoch(train)   [1][100/110]  lr: 1.0000e-01  eta: 0:37:23  time: 0.2045  data_time: 0.0108  memory: 3218  loss: 2.5376
# 06/10 12:41:32 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:41:34 - mmengine - INFO - Epoch(val) [1][27/27]    accuracy/top1: 28.6543  accuracy/top5: 71.9258  data_time: 0.0282  time: 0.0894
# 06/10 12:41:35 - mmengine - INFO - The best checkpoint with 28.6543 accuracy/top1 at 1 epoch is saved to best_accuracy_top1_epoch_1.pth.
# 06/10 12:41:55 - mmengine - INFO - Epoch(train)   [2][100/110]  lr: 1.0000e-01  eta: 0:36:44  time: 0.2047  data_time: 0.0098  memory: 3218  loss: 2.3522
# 06/10 12:41:57 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:42:00 - mmengine - INFO - Epoch(val) [2][27/27]    accuracy/top1: 32.3666  accuracy/top5: 77.2622  data_time: 0.0214  time: 0.0819
# 06/10 12:42:00 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_1.pth is removed
# 06/10 12:42:00 - mmengine - INFO - The best checkpoint with 32.3666 accuracy/top1 at 2 epoch is saved to best_accuracy_top1_epoch_2.pth.
# 06/10 12:42:20 - mmengine - INFO - Epoch(train)   [3][100/110]  lr: 1.0000e-01  eta: 0:36:16  time: 0.2039  data_time: 0.0094  memory: 3218  loss: 2.2605
# 06/10 12:42:22 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:42:24 - mmengine - INFO - Epoch(val) [3][27/27]    accuracy/top1: 32.5986  accuracy/top5: 77.3782  data_time: 0.0153  time: 0.0757
# 06/10 12:42:24 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_2.pth is removed
# 06/10 12:42:25 - mmengine - INFO - The best checkpoint with 32.5986 accuracy/top1 at 3 epoch is saved to best_accuracy_top1_epoch_3.pth.
# 06/10 12:42:46 - mmengine - INFO - Epoch(train)   [4][100/110]  lr: 1.0000e-01  eta: 0:36:00  time: 0.1984  data_time: 0.0048  memory: 3218  loss: 2.0650
# 06/10 12:42:48 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:42:50 - mmengine - INFO - Epoch(val) [4][27/27]    accuracy/top1: 38.3991  accuracy/top5: 80.6264  data_time: 0.0146  time: 0.0756
# 06/10 12:42:50 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_3.pth is removed
# 06/10 12:42:50 - mmengine - INFO - The best checkpoint with 38.3991 accuracy/top1 at 4 epoch is saved to best_accuracy_top1_epoch_4.pth.
# 06/10 12:43:11 - mmengine - INFO - Epoch(train)   [5][100/110]  lr: 1.0000e-01  eta: 0:35:33  time: 0.2002  data_time: 0.0059  memory: 3218  loss: 2.0500
# 06/10 12:43:12 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:43:15 - mmengine - INFO - Epoch(val) [5][27/27]    accuracy/top1: 37.8190  accuracy/top5: 84.2227  data_time: 0.0236  time: 0.0844
# 06/10 12:43:36 - mmengine - INFO - Epoch(train)   [6][100/110]  lr: 1.0000e-01  eta: 0:35:15  time: 0.2011  data_time: 0.0065  memory: 3218  loss: 2.1520
# 06/10 12:43:38 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:43:40 - mmengine - INFO - Epoch(val) [6][27/27]    accuracy/top1: 37.9350  accuracy/top5: 82.0186  data_time: 0.0243  time: 0.0856
# 06/10 12:44:01 - mmengine - INFO - Epoch(train)   [7][100/110]  lr: 1.0000e-01  eta: 0:34:55  time: 0.2019  data_time: 0.0059  memory: 3218  loss: 1.9207
# 06/10 12:44:03 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:44:05 - mmengine - INFO - Epoch(val) [7][27/27]    accuracy/top1: 43.2715  accuracy/top5: 84.8028  data_time: 0.0190  time: 0.0799
# 06/10 12:44:05 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_4.pth is removed
# 06/10 12:44:06 - mmengine - INFO - The best checkpoint with 43.2715 accuracy/top1 at 7 epoch is saved to best_accuracy_top1_epoch_7.pth.
# 06/10 12:44:26 - mmengine - INFO - Epoch(train)   [8][100/110]  lr: 1.0000e-01  eta: 0:34:32  time: 0.2047  data_time: 0.0094  memory: 3218  loss: 2.0149
# 06/10 12:44:28 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:44:31 - mmengine - INFO - Epoch(val) [8][27/27]    accuracy/top1: 43.0394  accuracy/top5: 85.4988  data_time: 0.0252  time: 0.0869
# 06/10 12:44:51 - mmengine - INFO - Epoch(train)   [9][100/110]  lr: 1.0000e-01  eta: 0:34:12  time: 0.1993  data_time: 0.0049  memory: 3218  loss: 1.7901
# 06/10 12:44:53 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:44:56 - mmengine - INFO - Epoch(val) [9][27/27]    accuracy/top1: 43.8515  accuracy/top5: 84.2227  data_time: 0.0157  time: 0.0767
# 06/10 12:44:56 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_7.pth is removed
# 06/10 12:44:56 - mmengine - INFO - The best checkpoint with 43.8515 accuracy/top1 at 9 epoch is saved to best_accuracy_top1_epoch_9.pth.
# 06/10 12:44:58 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:45:16 - mmengine - INFO - Epoch(train)  [10][100/110]  lr: 1.0000e-01  eta: 0:33:50  time: 0.2009  data_time: 0.0061  memory: 3218  loss: 1.7033
# 06/10 12:45:18 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:45:21 - mmengine - INFO - Epoch(val) [10][27/27]    accuracy/top1: 39.5592  accuracy/top5: 79.8144  data_time: 0.0204  time: 0.0815
# 06/10 12:45:41 - mmengine - INFO - Epoch(train)  [11][100/110]  lr: 1.0000e-01  eta: 0:33:28  time: 0.1985  data_time: 0.0041  memory: 3218  loss: 1.6234
# 06/10 12:45:43 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:45:46 - mmengine - INFO - Epoch(val) [11][27/27]    accuracy/top1: 48.7239  accuracy/top5: 86.8910  data_time: 0.0166  time: 0.0778
# 06/10 12:45:46 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_9.pth is removed
# 06/10 12:45:46 - mmengine - INFO - The best checkpoint with 48.7239 accuracy/top1 at 11 epoch is saved to best_accuracy_top1_epoch_11.pth.
# 06/10 12:46:06 - mmengine - INFO - Epoch(train)  [12][100/110]  lr: 1.0000e-01  eta: 0:33:04  time: 0.1992  data_time: 0.0046  memory: 3218  loss: 1.8098
# 06/10 12:46:08 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:46:11 - mmengine - INFO - Epoch(val) [12][27/27]    accuracy/top1: 49.4200  accuracy/top5: 87.7030  data_time: 0.0205  time: 0.0820
# 06/10 12:46:11 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_11.pth is removed
# 06/10 12:46:11 - mmengine - INFO - The best checkpoint with 49.4200 accuracy/top1 at 12 epoch is saved to best_accuracy_top1_epoch_12.pth.
# 06/10 12:46:31 - mmengine - INFO - Epoch(train)  [13][100/110]  lr: 1.0000e-01  eta: 0:32:40  time: 0.2007  data_time: 0.0050  memory: 3218  loss: 1.5336
# 06/10 12:46:33 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:46:36 - mmengine - INFO - Epoch(val) [13][27/27]    accuracy/top1: 51.5081  accuracy/top5: 88.5151  data_time: 0.0139  time: 0.0749
# 06/10 12:46:36 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_12.pth is removed
# 06/10 12:46:36 - mmengine - INFO - The best checkpoint with 51.5081 accuracy/top1 at 13 epoch is saved to best_accuracy_top1_epoch_13.pth.
# 06/10 12:46:56 - mmengine - INFO - Epoch(train)  [14][100/110]  lr: 1.0000e-01  eta: 0:32:17  time: 0.2003  data_time: 0.0048  memory: 3218  loss: 1.8035
# 06/10 12:46:58 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:47:01 - mmengine - INFO - Epoch(val) [14][27/27]    accuracy/top1: 52.5522  accuracy/top5: 88.5151  data_time: 0.0157  time: 0.0768
# 06/10 12:47:01 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_13.pth is removed
# 06/10 12:47:01 - mmengine - INFO - The best checkpoint with 52.5522 accuracy/top1 at 14 epoch is saved to best_accuracy_top1_epoch_14.pth.
# 06/10 12:47:21 - mmengine - INFO - Epoch(train)  [15][100/110]  lr: 1.0000e-01  eta: 0:31:54  time: 0.1998  data_time: 0.0052  memory: 3218  loss: 1.7786
# 06/10 12:47:23 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:47:26 - mmengine - INFO - Epoch(val) [15][27/27]    accuracy/top1: 48.8399  accuracy/top5: 88.6311  data_time: 0.0206  time: 0.0825
# 06/10 12:47:47 - mmengine - INFO - Epoch(train)  [16][100/110]  lr: 1.0000e-01  eta: 0:31:32  time: 0.2010  data_time: 0.0058  memory: 3218  loss: 1.3979
# 06/10 12:47:49 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:47:51 - mmengine - INFO - Epoch(val) [16][27/27]    accuracy/top1: 53.9443  accuracy/top5: 88.8631  data_time: 0.0184  time: 0.0795
# 06/10 12:47:51 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_14.pth is removed
# 06/10 12:47:51 - mmengine - INFO - The best checkpoint with 53.9443 accuracy/top1 at 16 epoch is saved to best_accuracy_top1_epoch_16.pth.
# 06/10 12:48:12 - mmengine - INFO - Epoch(train)  [17][100/110]  lr: 1.0000e-01  eta: 0:31:11  time: 0.2009  data_time: 0.0055  memory: 3218  loss: 1.4757
# 06/10 12:48:14 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:48:17 - mmengine - INFO - Epoch(val) [17][27/27]    accuracy/top1: 53.8283  accuracy/top5: 89.4432  data_time: 0.0236  time: 0.0855
# 06/10 12:48:37 - mmengine - INFO - Epoch(train)  [18][100/110]  lr: 1.0000e-01  eta: 0:30:49  time: 0.1995  data_time: 0.0043  memory: 3218  loss: 1.4415
# 06/10 12:48:39 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:48:41 - mmengine - INFO - Epoch(val) [18][27/27]    accuracy/top1: 50.3480  accuracy/top5: 87.8190  data_time: 0.0132  time: 0.0738
# 06/10 12:48:46 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:49:02 - mmengine - INFO - Epoch(train)  [19][100/110]  lr: 1.0000e-01  eta: 0:30:25  time: 0.2017  data_time: 0.0063  memory: 3218  loss: 1.3481
# 06/10 12:49:04 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:49:06 - mmengine - INFO - Epoch(val) [19][27/27]    accuracy/top1: 56.6125  accuracy/top5: 89.4432  data_time: 0.0173  time: 0.0785
# 06/10 12:49:06 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_16.pth is removed
# 06/10 12:49:06 - mmengine - INFO - The best checkpoint with 56.6125 accuracy/top1 at 19 epoch is saved to best_accuracy_top1_epoch_19.pth.
# 06/10 12:49:27 - mmengine - INFO - Epoch(train)  [20][100/110]  lr: 1.0000e-01  eta: 0:30:02  time: 0.2036  data_time: 0.0082  memory: 3218  loss: 1.4451
# 06/10 12:49:29 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:49:31 - mmengine - INFO - Epoch(val) [20][27/27]    accuracy/top1: 56.0325  accuracy/top5: 88.7471  data_time: 0.0128  time: 0.0731
# 06/10 12:49:51 - mmengine - INFO - Epoch(train)  [21][100/110]  lr: 1.0000e-01  eta: 0:29:40  time: 0.1989  data_time: 0.0045  memory: 3218  loss: 1.2508
# 06/10 12:49:53 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:49:56 - mmengine - INFO - Epoch(val) [21][27/27]    accuracy/top1: 57.5406  accuracy/top5: 89.3271  data_time: 0.0194  time: 0.0808
# 06/10 12:49:56 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_19.pth is removed
# 06/10 12:49:56 - mmengine - INFO - The best checkpoint with 57.5406 accuracy/top1 at 21 epoch is saved to best_accuracy_top1_epoch_21.pth.
# 06/10 12:50:17 - mmengine - INFO - Epoch(train)  [22][100/110]  lr: 1.0000e-01  eta: 0:29:18  time: 0.2020  data_time: 0.0072  memory: 3218  loss: 1.4140
# 06/10 12:50:19 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:50:21 - mmengine - INFO - Epoch(val) [22][27/27]    accuracy/top1: 55.8005  accuracy/top5: 89.4432  data_time: 0.0158  time: 0.0762
# 06/10 12:50:41 - mmengine - INFO - Epoch(train)  [23][100/110]  lr: 1.0000e-01  eta: 0:28:55  time: 0.2032  data_time: 0.0074  memory: 3218  loss: 1.2598
# 06/10 12:50:43 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:50:46 - mmengine - INFO - Epoch(val) [23][27/27]    accuracy/top1: 54.1763  accuracy/top5: 91.8793  data_time: 0.0146  time: 0.0759
# 06/10 12:51:06 - mmengine - INFO - Epoch(train)  [24][100/110]  lr: 1.0000e-01  eta: 0:28:32  time: 0.2051  data_time: 0.0098  memory: 3218  loss: 1.4615
# 06/10 12:51:08 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:51:10 - mmengine - INFO - Epoch(val) [24][27/27]    accuracy/top1: 56.2645  accuracy/top5: 90.4872  data_time: 0.0193  time: 0.0802
# 06/10 12:51:31 - mmengine - INFO - Epoch(train)  [25][100/110]  lr: 1.0000e-01  eta: 0:28:10  time: 0.2011  data_time: 0.0060  memory: 3218  loss: 1.3524
# 06/10 12:51:33 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:51:35 - mmengine - INFO - Epoch(val) [25][27/27]    accuracy/top1: 59.9768  accuracy/top5: 91.4153  data_time: 0.0136  time: 0.0739
# 06/10 12:51:35 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_21.pth is removed
# 06/10 12:51:35 - mmengine - INFO - The best checkpoint with 59.9768 accuracy/top1 at 25 epoch is saved to best_accuracy_top1_epoch_25.pth.
# 06/10 12:51:56 - mmengine - INFO - Epoch(train)  [26][100/110]  lr: 1.0000e-01  eta: 0:27:46  time: 0.2039  data_time: 0.0085  memory: 3218  loss: 1.3636
# 06/10 12:51:58 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:52:00 - mmengine - INFO - Epoch(val) [26][27/27]    accuracy/top1: 58.4687  accuracy/top5: 89.9072  data_time: 0.0193  time: 0.0802
# 06/10 12:52:20 - mmengine - INFO - Epoch(train)  [27][100/110]  lr: 1.0000e-01  eta: 0:27:24  time: 0.1991  data_time: 0.0041  memory: 3218  loss: 1.4829
# 06/10 12:52:22 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:52:25 - mmengine - INFO - Epoch(val) [27][27/27]    accuracy/top1: 61.7169  accuracy/top5: 91.0673  data_time: 0.0247  time: 0.0854
# 06/10 12:52:25 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_25.pth is removed
# 06/10 12:52:25 - mmengine - INFO - The best checkpoint with 61.7169 accuracy/top1 at 27 epoch is saved to best_accuracy_top1_epoch_27.pth.
# 06/10 12:52:31 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:52:46 - mmengine - INFO - Epoch(train)  [28][100/110]  lr: 1.0000e-01  eta: 0:27:01  time: 0.1988  data_time: 0.0046  memory: 3218  loss: 1.3228
# 06/10 12:52:47 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:52:50 - mmengine - INFO - Epoch(val) [28][27/27]    accuracy/top1: 57.0766  accuracy/top5: 90.8353  data_time: 0.0196  time: 0.0808
# 06/10 12:53:10 - mmengine - INFO - Epoch(train)  [29][100/110]  lr: 1.0000e-01  eta: 0:26:38  time: 0.1987  data_time: 0.0046  memory: 3218  loss: 1.2618
# 06/10 12:53:12 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:53:14 - mmengine - INFO - Epoch(val) [29][27/27]    accuracy/top1: 60.6729  accuracy/top5: 91.0673  data_time: 0.0186  time: 0.0804
# 06/10 12:53:35 - mmengine - INFO - Epoch(train)  [30][100/110]  lr: 1.0000e-01  eta: 0:26:15  time: 0.1991  data_time: 0.0047  memory: 3218  loss: 1.2687
# 06/10 12:53:37 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:53:39 - mmengine - INFO - Epoch(val) [30][27/27]    accuracy/top1: 59.1647  accuracy/top5: 91.8793  data_time: 0.0166  time: 0.0786
# 06/10 12:54:00 - mmengine - INFO - Epoch(train)  [31][100/110]  lr: 1.0000e-02  eta: 0:25:53  time: 0.2014  data_time: 0.0060  memory: 3218  loss: 0.9375
# 06/10 12:54:02 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:54:04 - mmengine - INFO - Epoch(val) [31][27/27]    accuracy/top1: 69.8376  accuracy/top5: 93.9675  data_time: 0.0177  time: 0.0790
# 06/10 12:54:04 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_27.pth is removed
# 06/10 12:54:04 - mmengine - INFO - The best checkpoint with 69.8376 accuracy/top1 at 31 epoch is saved to best_accuracy_top1_epoch_31.pth.
# 06/10 12:54:25 - mmengine - INFO - Epoch(train)  [32][100/110]  lr: 1.0000e-02  eta: 0:25:30  time: 0.2013  data_time: 0.0065  memory: 3218  loss: 0.9510
# 06/10 12:54:27 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:54:29 - mmengine - INFO - Epoch(val) [32][27/27]    accuracy/top1: 71.2297  accuracy/top5: 93.7355  data_time: 0.0163  time: 0.0770
# 06/10 12:54:29 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_31.pth is removed
# 06/10 12:54:30 - mmengine - INFO - The best checkpoint with 71.2297 accuracy/top1 at 32 epoch is saved to best_accuracy_top1_epoch_32.pth.
# 06/10 12:54:50 - mmengine - INFO - Epoch(train)  [33][100/110]  lr: 1.0000e-02  eta: 0:25:08  time: 0.2011  data_time: 0.0063  memory: 3218  loss: 0.9087
# 06/10 12:54:52 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:54:54 - mmengine - INFO - Epoch(val) [33][27/27]    accuracy/top1: 70.4176  accuracy/top5: 94.5476  data_time: 0.0137  time: 0.0747
# 06/10 12:55:15 - mmengine - INFO - Epoch(train)  [34][100/110]  lr: 1.0000e-02  eta: 0:24:45  time: 0.2011  data_time: 0.0063  memory: 3218  loss: 0.7433
# 06/10 12:55:17 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:55:19 - mmengine - INFO - Epoch(val) [34][27/27]    accuracy/top1: 71.4617  accuracy/top5: 94.0835  data_time: 0.0152  time: 0.0765
# 06/10 12:55:19 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_32.pth is removed
# 06/10 12:55:19 - mmengine - INFO - The best checkpoint with 71.4617 accuracy/top1 at 34 epoch is saved to best_accuracy_top1_epoch_34.pth.
# 06/10 12:55:40 - mmengine - INFO - Epoch(train)  [35][100/110]  lr: 1.0000e-02  eta: 0:24:22  time: 0.2015  data_time: 0.0066  memory: 3218  loss: 0.7759
# 06/10 12:55:41 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:55:44 - mmengine - INFO - Epoch(val) [35][27/27]    accuracy/top1: 69.7216  accuracy/top5: 93.9675  data_time: 0.0231  time: 0.0842
# 06/10 12:56:04 - mmengine - INFO - Epoch(train)  [36][100/110]  lr: 1.0000e-02  eta: 0:24:00  time: 0.2031  data_time: 0.0079  memory: 3218  loss: 0.8948
# 06/10 12:56:06 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:56:09 - mmengine - INFO - Epoch(val) [36][27/27]    accuracy/top1: 70.0696  accuracy/top5: 93.8515  data_time: 0.0240  time: 0.0861
# 06/10 12:56:17 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:56:30 - mmengine - INFO - Epoch(train)  [37][100/110]  lr: 1.0000e-02  eta: 0:23:38  time: 0.2010  data_time: 0.0054  memory: 3218  loss: 0.8788
# 06/10 12:56:32 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:56:34 - mmengine - INFO - Epoch(val) [37][27/27]    accuracy/top1: 70.7657  accuracy/top5: 94.6636  data_time: 0.0174  time: 0.0794
# 06/10 12:56:55 - mmengine - INFO - Epoch(train)  [38][100/110]  lr: 1.0000e-02  eta: 0:23:16  time: 0.2050  data_time: 0.0101  memory: 3218  loss: 0.7200
# 06/10 12:56:57 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:56:59 - mmengine - INFO - Epoch(val) [38][27/27]    accuracy/top1: 71.9258  accuracy/top5: 95.3596  data_time: 0.0165  time: 0.0782
# 06/10 12:56:59 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_34.pth is removed
# 06/10 12:57:00 - mmengine - INFO - The best checkpoint with 71.9258 accuracy/top1 at 38 epoch is saved to best_accuracy_top1_epoch_38.pth.
# 06/10 12:57:20 - mmengine - INFO - Epoch(train)  [39][100/110]  lr: 1.0000e-02  eta: 0:22:54  time: 0.2028  data_time: 0.0070  memory: 3218  loss: 0.7900
# 06/10 12:57:22 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:57:24 - mmengine - INFO - Epoch(val) [39][27/27]    accuracy/top1: 72.1578  accuracy/top5: 94.5476  data_time: 0.0141  time: 0.0751
# 06/10 12:57:24 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_38.pth is removed
# 06/10 12:57:25 - mmengine - INFO - The best checkpoint with 72.1578 accuracy/top1 at 39 epoch is saved to best_accuracy_top1_epoch_39.pth.
# 06/10 12:57:46 - mmengine - INFO - Epoch(train)  [40][100/110]  lr: 1.0000e-02  eta: 0:22:31  time: 0.2020  data_time: 0.0066  memory: 3218  loss: 0.7284
# 06/10 12:57:48 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:57:50 - mmengine - INFO - Epoch(val) [40][27/27]    accuracy/top1: 71.8097  accuracy/top5: 94.1995  data_time: 0.0212  time: 0.0822
# 06/10 12:58:10 - mmengine - INFO - Epoch(train)  [41][100/110]  lr: 1.0000e-02  eta: 0:22:09  time: 0.2029  data_time: 0.0070  memory: 3218  loss: 0.8805
# 06/10 12:58:12 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:58:15 - mmengine - INFO - Epoch(val) [41][27/27]    accuracy/top1: 71.6937  accuracy/top5: 94.8956  data_time: 0.0265  time: 0.0889
# 06/10 12:58:35 - mmengine - INFO - Epoch(train)  [42][100/110]  lr: 1.0000e-02  eta: 0:21:46  time: 0.2017  data_time: 0.0065  memory: 3218  loss: 0.7169
# 06/10 12:58:37 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:58:40 - mmengine - INFO - Epoch(val) [42][27/27]    accuracy/top1: 72.7378  accuracy/top5: 94.6636  data_time: 0.0240  time: 0.0850
# 06/10 12:58:40 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_39.pth is removed
# 06/10 12:58:40 - mmengine - INFO - The best checkpoint with 72.7378 accuracy/top1 at 42 epoch is saved to best_accuracy_top1_epoch_42.pth.
# 06/10 12:59:01 - mmengine - INFO - Epoch(train)  [43][100/110]  lr: 1.0000e-02  eta: 0:21:24  time: 0.2015  data_time: 0.0062  memory: 3218  loss: 0.7088
# 06/10 12:59:03 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:59:05 - mmengine - INFO - Epoch(val) [43][27/27]    accuracy/top1: 72.7378  accuracy/top5: 94.8956  data_time: 0.0152  time: 0.0764
# 06/10 12:59:26 - mmengine - INFO - Epoch(train)  [44][100/110]  lr: 1.0000e-02  eta: 0:21:01  time: 0.2088  data_time: 0.0133  memory: 3218  loss: 0.5846
# 06/10 12:59:28 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:59:30 - mmengine - INFO - Epoch(val) [44][27/27]    accuracy/top1: 70.4176  accuracy/top5: 95.3596  data_time: 0.0259  time: 0.0868
# 06/10 12:59:50 - mmengine - INFO - Epoch(train)  [45][100/110]  lr: 1.0000e-02  eta: 0:20:39  time: 0.2049  data_time: 0.0097  memory: 3218  loss: 0.6930
# 06/10 12:59:52 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 12:59:55 - mmengine - INFO - Epoch(val) [45][27/27]    accuracy/top1: 72.5058  accuracy/top5: 94.4316  data_time: 0.0175  time: 0.0777
# 06/10 13:00:05 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:00:15 - mmengine - INFO - Epoch(train)  [46][100/110]  lr: 1.0000e-02  eta: 0:20:16  time: 0.1989  data_time: 0.0046  memory: 3218  loss: 0.7390
# 06/10 13:00:17 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:00:19 - mmengine - INFO - Epoch(val) [46][27/27]    accuracy/top1: 70.9977  accuracy/top5: 94.8956  data_time: 0.0150  time: 0.0755
# 06/10 13:00:40 - mmengine - INFO - Epoch(train)  [47][100/110]  lr: 1.0000e-02  eta: 0:19:54  time: 0.2040  data_time: 0.0088  memory: 3218  loss: 0.7003
# 06/10 13:00:42 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:00:44 - mmengine - INFO - Epoch(val) [47][27/27]    accuracy/top1: 72.7378  accuracy/top5: 95.2436  data_time: 0.0150  time: 0.0760
# 06/10 13:01:05 - mmengine - INFO - Epoch(train)  [48][100/110]  lr: 1.0000e-02  eta: 0:19:31  time: 0.2003  data_time: 0.0053  memory: 3218  loss: 0.6194
# 06/10 13:01:07 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:01:09 - mmengine - INFO - Epoch(val) [48][27/27]    accuracy/top1: 72.8538  accuracy/top5: 95.1276  data_time: 0.0150  time: 0.0762
# 06/10 13:01:09 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_42.pth is removed
# 06/10 13:01:09 - mmengine - INFO - The best checkpoint with 72.8538 accuracy/top1 at 48 epoch is saved to best_accuracy_top1_epoch_48.pth.
# 06/10 13:01:30 - mmengine - INFO - Epoch(train)  [49][100/110]  lr: 1.0000e-02  eta: 0:19:09  time: 0.2016  data_time: 0.0069  memory: 3218  loss: 0.5554
# 06/10 13:01:32 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:01:34 - mmengine - INFO - Epoch(val) [49][27/27]    accuracy/top1: 71.2297  accuracy/top5: 94.4316  data_time: 0.0145  time: 0.0755
# 06/10 13:01:54 - mmengine - INFO - Epoch(train)  [50][100/110]  lr: 1.0000e-02  eta: 0:18:46  time: 0.2073  data_time: 0.0109  memory: 3218  loss: 0.7712
# 06/10 13:01:56 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:01:56 - mmengine - INFO - Saving checkpoint at 50 epochs
# 06/10 13:01:59 - mmengine - INFO - Epoch(val) [50][27/27]    accuracy/top1: 72.6218  accuracy/top5: 94.4316  data_time: 0.0174  time: 0.0788
# 06/10 13:02:20 - mmengine - INFO - Epoch(train)  [51][100/110]  lr: 1.0000e-02  eta: 0:18:24  time: 0.1985  data_time: 0.0042  memory: 3218  loss: 0.6984
# 06/10 13:02:22 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:02:24 - mmengine - INFO - Epoch(val) [51][27/27]    accuracy/top1: 72.6218  accuracy/top5: 95.0116  data_time: 0.0173  time: 0.0786
# 06/10 13:02:45 - mmengine - INFO - Epoch(train)  [52][100/110]  lr: 1.0000e-02  eta: 0:18:02  time: 0.2070  data_time: 0.0109  memory: 3218  loss: 0.5585
# 06/10 13:02:47 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:02:49 - mmengine - INFO - Epoch(val) [52][27/27]    accuracy/top1: 72.9698  accuracy/top5: 95.4756  data_time: 0.0163  time: 0.0779
# 06/10 13:02:49 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_48.pth is removed
# 06/10 13:02:50 - mmengine - INFO - The best checkpoint with 72.9698 accuracy/top1 at 52 epoch is saved to best_accuracy_top1_epoch_52.pth.
# 06/10 13:03:10 - mmengine - INFO - Epoch(train)  [53][100/110]  lr: 1.0000e-02  eta: 0:17:39  time: 0.1990  data_time: 0.0042  memory: 3218  loss: 0.6336
# 06/10 13:03:12 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:03:15 - mmengine - INFO - Epoch(val) [53][27/27]    accuracy/top1: 72.5058  accuracy/top5: 95.0116  data_time: 0.0179  time: 0.0793
# 06/10 13:03:35 - mmengine - INFO - Epoch(train)  [54][100/110]  lr: 1.0000e-02  eta: 0:17:16  time: 0.2055  data_time: 0.0097  memory: 3218  loss: 0.6505
# 06/10 13:03:37 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:03:40 - mmengine - INFO - Epoch(val) [54][27/27]    accuracy/top1: 74.3619  accuracy/top5: 95.0116  data_time: 0.0257  time: 0.0864
# 06/10 13:03:40 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_52.pth is removed
# 06/10 13:03:40 - mmengine - INFO - The best checkpoint with 74.3619 accuracy/top1 at 54 epoch is saved to best_accuracy_top1_epoch_54.pth.
# 06/10 13:03:53 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:04:01 - mmengine - INFO - Epoch(train)  [55][100/110]  lr: 1.0000e-02  eta: 0:16:54  time: 0.1995  data_time: 0.0051  memory: 3218  loss: 0.6423
# 06/10 13:04:03 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:04:05 - mmengine - INFO - Epoch(val) [55][27/27]    accuracy/top1: 73.2019  accuracy/top5: 95.1276  data_time: 0.0168  time: 0.0789
# 06/10 13:04:25 - mmengine - INFO - Epoch(train)  [56][100/110]  lr: 1.0000e-02  eta: 0:16:31  time: 0.2037  data_time: 0.0082  memory: 3218  loss: 0.6252
# 06/10 13:04:27 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:04:30 - mmengine - INFO - Epoch(val) [56][27/27]    accuracy/top1: 72.3898  accuracy/top5: 94.4316  data_time: 0.0203  time: 0.0831
# 06/10 13:04:50 - mmengine - INFO - Epoch(train)  [57][100/110]  lr: 1.0000e-02  eta: 0:16:09  time: 0.2001  data_time: 0.0049  memory: 3218  loss: 0.6362
# 06/10 13:04:52 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:04:55 - mmengine - INFO - Epoch(val) [57][27/27]    accuracy/top1: 69.8376  accuracy/top5: 94.8956  data_time: 0.0232  time: 0.0844
# 06/10 13:05:15 - mmengine - INFO - Epoch(train)  [58][100/110]  lr: 1.0000e-02  eta: 0:15:46  time: 0.2042  data_time: 0.0086  memory: 3218  loss: 0.5903
# 06/10 13:05:17 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:05:20 - mmengine - INFO - Epoch(val) [58][27/27]    accuracy/top1: 73.5499  accuracy/top5: 94.6636  data_time: 0.0281  time: 0.0903
# 06/10 13:05:40 - mmengine - INFO - Epoch(train)  [59][100/110]  lr: 1.0000e-02  eta: 0:15:24  time: 0.2004  data_time: 0.0055  memory: 3218  loss: 0.5655
# 06/10 13:05:42 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:05:44 - mmengine - INFO - Epoch(val) [59][27/27]    accuracy/top1: 71.6937  accuracy/top5: 94.4316  data_time: 0.0146  time: 0.0755
# 06/10 13:06:05 - mmengine - INFO - Epoch(train)  [60][100/110]  lr: 1.0000e-02  eta: 0:15:01  time: 0.2071  data_time: 0.0112  memory: 3218  loss: 0.7072
# 06/10 13:06:07 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:06:09 - mmengine - INFO - Epoch(val) [60][27/27]    accuracy/top1: 72.8538  accuracy/top5: 94.3155  data_time: 0.0176  time: 0.0779
# 06/10 13:06:30 - mmengine - INFO - Epoch(train)  [61][100/110]  lr: 1.0000e-03  eta: 0:14:39  time: 0.2038  data_time: 0.0084  memory: 3218  loss: 0.4261
# 06/10 13:06:32 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:06:34 - mmengine - INFO - Epoch(val) [61][27/27]    accuracy/top1: 74.2459  accuracy/top5: 95.3596  data_time: 0.0170  time: 0.0784
# 06/10 13:06:54 - mmengine - INFO - Epoch(train)  [62][100/110]  lr: 1.0000e-03  eta: 0:14:16  time: 0.2011  data_time: 0.0058  memory: 3218  loss: 0.5396
# 06/10 13:06:56 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:06:59 - mmengine - INFO - Epoch(val) [62][27/27]    accuracy/top1: 73.3179  accuracy/top5: 95.4756  data_time: 0.0165  time: 0.0769
# 06/10 13:07:19 - mmengine - INFO - Epoch(train)  [63][100/110]  lr: 1.0000e-03  eta: 0:13:54  time: 0.2035  data_time: 0.0081  memory: 3218  loss: 0.5512
# 06/10 13:07:21 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:07:24 - mmengine - INFO - Epoch(val) [63][27/27]    accuracy/top1: 74.4780  accuracy/top5: 95.2436  data_time: 0.0188  time: 0.0797
# 06/10 13:07:24 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_54.pth is removed
# 06/10 13:07:24 - mmengine - INFO - The best checkpoint with 74.4780 accuracy/top1 at 63 epoch is saved to best_accuracy_top1_epoch_63.pth.
# 06/10 13:07:39 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:07:45 - mmengine - INFO - Epoch(train)  [64][100/110]  lr: 1.0000e-03  eta: 0:13:31  time: 0.1989  data_time: 0.0046  memory: 3218  loss: 0.5681
# 06/10 13:07:47 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:07:50 - mmengine - INFO - Epoch(val) [64][27/27]    accuracy/top1: 74.8260  accuracy/top5: 95.1276  data_time: 0.0212  time: 0.0827
# 06/10 13:07:50 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_63.pth is removed
# 06/10 13:07:50 - mmengine - INFO - The best checkpoint with 74.8260 accuracy/top1 at 64 epoch is saved to best_accuracy_top1_epoch_64.pth.
# 06/10 13:08:11 - mmengine - INFO - Epoch(train)  [65][100/110]  lr: 1.0000e-03  eta: 0:13:09  time: 0.1992  data_time: 0.0046  memory: 3218  loss: 0.5785
# 06/10 13:08:13 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:08:15 - mmengine - INFO - Epoch(val) [65][27/27]    accuracy/top1: 73.8979  accuracy/top5: 95.4756  data_time: 0.0143  time: 0.0749
# 06/10 13:08:36 - mmengine - INFO - Epoch(train)  [66][100/110]  lr: 1.0000e-03  eta: 0:12:46  time: 0.2010  data_time: 0.0062  memory: 3218  loss: 0.5513
# 06/10 13:08:38 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:08:40 - mmengine - INFO - Epoch(val) [66][27/27]    accuracy/top1: 74.3619  accuracy/top5: 95.0116  data_time: 0.0201  time: 0.0821
# 06/10 13:09:01 - mmengine - INFO - Epoch(train)  [67][100/110]  lr: 1.0000e-03  eta: 0:12:24  time: 0.2002  data_time: 0.0049  memory: 3218  loss: 0.4045
# 06/10 13:09:03 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:09:05 - mmengine - INFO - Epoch(val) [67][27/27]    accuracy/top1: 73.6659  accuracy/top5: 95.5916  data_time: 0.0262  time: 0.0872
# 06/10 13:09:26 - mmengine - INFO - Epoch(train)  [68][100/110]  lr: 1.0000e-03  eta: 0:12:01  time: 0.2034  data_time: 0.0067  memory: 3218  loss: 0.4058
# 06/10 13:09:28 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:09:30 - mmengine - INFO - Epoch(val) [68][27/27]    accuracy/top1: 74.3619  accuracy/top5: 95.4756  data_time: 0.0234  time: 0.0861
# 06/10 13:09:51 - mmengine - INFO - Epoch(train)  [69][100/110]  lr: 1.0000e-03  eta: 0:11:39  time: 0.2042  data_time: 0.0080  memory: 3218  loss: 0.4818
# 06/10 13:09:53 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:09:55 - mmengine - INFO - Epoch(val) [69][27/27]    accuracy/top1: 74.1299  accuracy/top5: 95.3596  data_time: 0.0190  time: 0.0817
# 06/10 13:10:16 - mmengine - INFO - Epoch(train)  [70][100/110]  lr: 1.0000e-03  eta: 0:11:16  time: 0.2049  data_time: 0.0096  memory: 3218  loss: 0.6665
# 06/10 13:10:18 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:10:20 - mmengine - INFO - Epoch(val) [70][27/27]    accuracy/top1: 73.4339  accuracy/top5: 95.5916  data_time: 0.0141  time: 0.0750
# 06/10 13:10:41 - mmengine - INFO - Epoch(train)  [71][100/110]  lr: 1.0000e-03  eta: 0:10:54  time: 0.2008  data_time: 0.0060  memory: 3218  loss: 0.5471
# 06/10 13:10:43 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:10:45 - mmengine - INFO - Epoch(val) [71][27/27]    accuracy/top1: 73.7819  accuracy/top5: 95.4756  data_time: 0.0231  time: 0.0834
# 06/10 13:11:06 - mmengine - INFO - Epoch(train)  [72][100/110]  lr: 1.0000e-03  eta: 0:10:31  time: 0.1999  data_time: 0.0056  memory: 3218  loss: 0.5812
# 06/10 13:11:08 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:11:10 - mmengine - INFO - Epoch(val) [72][27/27]    accuracy/top1: 74.5940  accuracy/top5: 95.5916  data_time: 0.0266  time: 0.0875
# 06/10 13:11:27 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:11:31 - mmengine - INFO - Epoch(train)  [73][100/110]  lr: 1.0000e-03  eta: 0:10:09  time: 0.2011  data_time: 0.0058  memory: 3218  loss: 0.4020
# 06/10 13:11:33 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:11:35 - mmengine - INFO - Epoch(val) [73][27/27]    accuracy/top1: 75.0580  accuracy/top5: 95.2436  data_time: 0.0174  time: 0.0794
# 06/10 13:11:35 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_64.pth is removed
# 06/10 13:11:35 - mmengine - INFO - The best checkpoint with 75.0580 accuracy/top1 at 73 epoch is saved to best_accuracy_top1_epoch_73.pth.
# 06/10 13:11:56 - mmengine - INFO - Epoch(train)  [74][100/110]  lr: 1.0000e-03  eta: 0:09:46  time: 0.2032  data_time: 0.0078  memory: 3218  loss: 0.4883
# 06/10 13:11:58 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:12:00 - mmengine - INFO - Epoch(val) [74][27/27]    accuracy/top1: 74.4780  accuracy/top5: 95.2436  data_time: 0.0184  time: 0.0798
# 06/10 13:12:21 - mmengine - INFO - Epoch(train)  [75][100/110]  lr: 1.0000e-03  eta: 0:09:24  time: 0.1995  data_time: 0.0051  memory: 3218  loss: 0.4421
# 06/10 13:12:23 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:12:25 - mmengine - INFO - Epoch(val) [75][27/27]    accuracy/top1: 74.2459  accuracy/top5: 95.4756  data_time: 0.0167  time: 0.0774
# 06/10 13:12:46 - mmengine - INFO - Epoch(train)  [76][100/110]  lr: 1.0000e-03  eta: 0:09:01  time: 0.2033  data_time: 0.0080  memory: 3218  loss: 0.5157
# 06/10 13:12:48 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:12:50 - mmengine - INFO - Epoch(val) [76][27/27]    accuracy/top1: 73.8979  accuracy/top5: 95.5916  data_time: 0.0217  time: 0.0835
# 06/10 13:13:10 - mmengine - INFO - Epoch(train)  [77][100/110]  lr: 1.0000e-03  eta: 0:08:39  time: 0.2032  data_time: 0.0074  memory: 3218  loss: 0.3997
# 06/10 13:13:12 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:13:15 - mmengine - INFO - Epoch(val) [77][27/27]    accuracy/top1: 75.1740  accuracy/top5: 95.3596  data_time: 0.0156  time: 0.0769
# 06/10 13:13:15 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_73.pth is removed
# 06/10 13:13:15 - mmengine - INFO - The best checkpoint with 75.1740 accuracy/top1 at 77 epoch is saved to best_accuracy_top1_epoch_77.pth.
# 06/10 13:13:36 - mmengine - INFO - Epoch(train)  [78][100/110]  lr: 1.0000e-03  eta: 0:08:16  time: 0.2020  data_time: 0.0071  memory: 3218  loss: 0.4320
# 06/10 13:13:38 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:13:40 - mmengine - INFO - Epoch(val) [78][27/27]    accuracy/top1: 73.3179  accuracy/top5: 95.8237  data_time: 0.0175  time: 0.0797
# 06/10 13:14:01 - mmengine - INFO - Epoch(train)  [79][100/110]  lr: 1.0000e-03  eta: 0:07:54  time: 0.1993  data_time: 0.0048  memory: 3218  loss: 0.4974
# 06/10 13:14:03 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:14:05 - mmengine - INFO - Epoch(val) [79][27/27]    accuracy/top1: 73.6659  accuracy/top5: 95.3596  data_time: 0.0246  time: 0.0852
# 06/10 13:14:26 - mmengine - INFO - Epoch(train)  [80][100/110]  lr: 1.0000e-03  eta: 0:07:31  time: 0.1993  data_time: 0.0049  memory: 3218  loss: 0.4294
# 06/10 13:14:28 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:14:30 - mmengine - INFO - Epoch(val) [80][27/27]    accuracy/top1: 74.1299  accuracy/top5: 95.7077  data_time: 0.0125  time: 0.0729
# 06/10 13:14:50 - mmengine - INFO - Epoch(train)  [81][100/110]  lr: 1.0000e-03  eta: 0:07:09  time: 0.1993  data_time: 0.0043  memory: 3218  loss: 0.4650
# 06/10 13:14:52 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:14:55 - mmengine - INFO - Epoch(val) [81][27/27]    accuracy/top1: 74.4780  accuracy/top5: 95.1276  data_time: 0.0172  time: 0.0774
# 06/10 13:15:13 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:15:15 - mmengine - INFO - Epoch(train)  [82][100/110]  lr: 1.0000e-03  eta: 0:06:46  time: 0.2040  data_time: 0.0091  memory: 3218  loss: 0.3656
# 06/10 13:15:17 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:15:19 - mmengine - INFO - Epoch(val) [82][27/27]    accuracy/top1: 74.0139  accuracy/top5: 95.5916  data_time: 0.0145  time: 0.0755
# 06/10 13:15:40 - mmengine - INFO - Epoch(train)  [83][100/110]  lr: 1.0000e-03  eta: 0:06:24  time: 0.1998  data_time: 0.0049  memory: 3218  loss: 0.4597
# 06/10 13:15:42 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:15:44 - mmengine - INFO - Epoch(val) [83][27/27]    accuracy/top1: 73.4339  accuracy/top5: 95.7077  data_time: 0.0147  time: 0.0754
# 06/10 13:16:04 - mmengine - INFO - Epoch(train)  [84][100/110]  lr: 1.0000e-03  eta: 0:06:01  time: 0.2026  data_time: 0.0070  memory: 3218  loss: 0.4923
# 06/10 13:16:06 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:16:09 - mmengine - INFO - Epoch(val) [84][27/27]    accuracy/top1: 74.0139  accuracy/top5: 95.8237  data_time: 0.0175  time: 0.0788
# 06/10 13:16:30 - mmengine - INFO - Epoch(train)  [85][100/110]  lr: 1.0000e-03  eta: 0:05:39  time: 0.2013  data_time: 0.0063  memory: 3218  loss: 0.4397
# 06/10 13:16:32 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:16:34 - mmengine - INFO - Epoch(val) [85][27/27]    accuracy/top1: 74.8260  accuracy/top5: 95.7077  data_time: 0.0221  time: 0.0840
# 06/10 13:16:55 - mmengine - INFO - Epoch(train)  [86][100/110]  lr: 1.0000e-03  eta: 0:05:17  time: 0.2045  data_time: 0.0088  memory: 3218  loss: 0.3813
# 06/10 13:16:57 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:16:59 - mmengine - INFO - Epoch(val) [86][27/27]    accuracy/top1: 74.2459  accuracy/top5: 95.4756  data_time: 0.0201  time: 0.0809
# 06/10 13:17:20 - mmengine - INFO - Epoch(train)  [87][100/110]  lr: 1.0000e-03  eta: 0:04:54  time: 0.2045  data_time: 0.0086  memory: 3218  loss: 0.3981
# 06/10 13:17:21 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:17:24 - mmengine - INFO - Epoch(val) [87][27/27]    accuracy/top1: 74.1299  accuracy/top5: 95.2436  data_time: 0.0220  time: 0.0823
# 06/10 13:17:44 - mmengine - INFO - Epoch(train)  [88][100/110]  lr: 1.0000e-03  eta: 0:04:32  time: 0.2044  data_time: 0.0087  memory: 3218  loss: 0.4343
# 06/10 13:17:46 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:17:48 - mmengine - INFO - Epoch(val) [88][27/27]    accuracy/top1: 75.5220  accuracy/top5: 95.2436  data_time: 0.0161  time: 0.0772
# 06/10 13:17:48 - mmengine - INFO - The previous best checkpoint /mmpretrain/xuchenworkspace/ImageClassifier/best_accuracy_top1_epoch_77.pth is removed
# 06/10 13:17:49 - mmengine - INFO - The best checkpoint with 75.5220 accuracy/top1 at 88 epoch is saved to best_accuracy_top1_epoch_88.pth.
# 06/10 13:18:10 - mmengine - INFO - Epoch(train)  [89][100/110]  lr: 1.0000e-03  eta: 0:04:09  time: 0.2015  data_time: 0.0060  memory: 3218  loss: 0.4327
# 06/10 13:18:12 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:18:14 - mmengine - INFO - Epoch(val) [89][27/27]    accuracy/top1: 74.4780  accuracy/top5: 95.2436  data_time: 0.0173  time: 0.0782
# 06/10 13:18:34 - mmengine - INFO - Epoch(train)  [90][100/110]  lr: 1.0000e-03  eta: 0:03:46  time: 0.2126  data_time: 0.0157  memory: 3218  loss: 0.4130
# 06/10 13:18:36 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:18:38 - mmengine - INFO - Epoch(val) [90][27/27]    accuracy/top1: 73.4339  accuracy/top5: 95.3596  data_time: 0.0200  time: 0.0817
# 06/10 13:18:59 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:18:59 - mmengine - INFO - Epoch(train)  [91][100/110]  lr: 1.0000e-04  eta: 0:03:24  time: 0.2000  data_time: 0.0050  memory: 3218  loss: 0.4480
# 06/10 13:19:01 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:19:03 - mmengine - INFO - Epoch(val) [91][27/27]    accuracy/top1: 74.5940  accuracy/top5: 95.0116  data_time: 0.0156  time: 0.0768
# 06/10 13:19:24 - mmengine - INFO - Epoch(train)  [92][100/110]  lr: 1.0000e-04  eta: 0:03:01  time: 0.2038  data_time: 0.0075  memory: 3218  loss: 0.4854
# 06/10 13:19:26 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:19:28 - mmengine - INFO - Epoch(val) [92][27/27]    accuracy/top1: 74.5940  accuracy/top5: 95.3596  data_time: 0.0217  time: 0.0827
# 06/10 13:19:49 - mmengine - INFO - Epoch(train)  [93][100/110]  lr: 1.0000e-04  eta: 0:02:39  time: 0.2045  data_time: 0.0090  memory: 3218  loss: 0.4260
# 06/10 13:19:51 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:19:53 - mmengine - INFO - Epoch(val) [93][27/27]    accuracy/top1: 74.3619  accuracy/top5: 95.3596  data_time: 0.0168  time: 0.0777
# 06/10 13:20:13 - mmengine - INFO - Epoch(train)  [94][100/110]  lr: 1.0000e-04  eta: 0:02:17  time: 0.2008  data_time: 0.0055  memory: 3218  loss: 0.4622
# 06/10 13:20:15 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:20:18 - mmengine - INFO - Epoch(val) [94][27/27]    accuracy/top1: 73.8979  accuracy/top5: 95.2436  data_time: 0.0179  time: 0.0797
# 06/10 13:20:38 - mmengine - INFO - Epoch(train)  [95][100/110]  lr: 1.0000e-04  eta: 0:01:54  time: 0.2033  data_time: 0.0075  memory: 3218  loss: 0.5440
# 06/10 13:20:40 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:20:43 - mmengine - INFO - Epoch(val) [95][27/27]    accuracy/top1: 74.2459  accuracy/top5: 95.1276  data_time: 0.0245  time: 0.0862
# 06/10 13:21:03 - mmengine - INFO - Epoch(train)  [96][100/110]  lr: 1.0000e-04  eta: 0:01:32  time: 0.2005  data_time: 0.0048  memory: 3218  loss: 0.3650
# 06/10 13:21:05 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:21:07 - mmengine - INFO - Epoch(val) [96][27/27]    accuracy/top1: 73.6659  accuracy/top5: 95.3596  data_time: 0.0150  time: 0.0762
# 06/10 13:21:28 - mmengine - INFO - Epoch(train)  [97][100/110]  lr: 1.0000e-04  eta: 0:01:09  time: 0.1994  data_time: 0.0047  memory: 3218  loss: 0.4494
# 06/10 13:21:30 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:21:32 - mmengine - INFO - Epoch(val) [97][27/27]    accuracy/top1: 73.3179  accuracy/top5: 95.2436  data_time: 0.0220  time: 0.0826
# 06/10 13:21:53 - mmengine - INFO - Epoch(train)  [98][100/110]  lr: 1.0000e-04  eta: 0:00:47  time: 0.2028  data_time: 0.0069  memory: 3218  loss: 0.4196
# 06/10 13:21:55 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:21:57 - mmengine - INFO - Epoch(val) [98][27/27]    accuracy/top1: 74.5940  accuracy/top5: 95.1276  data_time: 0.0169  time: 0.0788
# 06/10 13:22:17 - mmengine - INFO - Epoch(train)  [99][100/110]  lr: 1.0000e-04  eta: 0:00:24  time: 0.2029  data_time: 0.0079  memory: 3218  loss: 0.3973
# 06/10 13:22:19 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:22:22 - mmengine - INFO - Epoch(val) [99][27/27]    accuracy/top1: 74.0139  accuracy/top5: 95.0116  data_time: 0.0253  time: 0.0865
# 06/10 13:22:42 - mmengine - INFO - Epoch(train) [100][100/110]  lr: 1.0000e-04  eta: 0:00:02  time: 0.1988  data_time: 0.0045  memory: 3218  loss: 0.5213
# 06/10 13:22:44 - mmengine - INFO - Exp name: resnet50_8xb32_in1k_20230610_124108
# 06/10 13:22:44 - mmengine - INFO - Saving checkpoint at 100 epochs
# 06/10 13:22:47 - mmengine - INFO - Epoch(val) [100][27/27]    accuracy/top1: 75.4060  accuracy/top5: 95.1276  data_time: 0.0158  time: 0.0763

# %% [markdown]
# ## 5、使用 MMPreTrain 的 ImageClassificationInferencer 接口，对网络水果图像，或自己拍摄的水果图像，使用训练好的模型进行分类

# %%
from mmpretrain import ImageClassificationInferencer

# %%
inferencer = ImageClassificationInferencer('ImageClassifier/resnet50_8xb32_in1k.py', pretrained='ImageClassifier/best_accuracy_top1_epoch_88.pth')
# Out:
# Loads checkpoint by local backend from path: ImageClassifier/best_accuracy_top1_epoch_88.pth

# %%
inferencer("/mmpretrain/data_split/train/圣女果/4.jpg", show=True)
# Out:
# 06/10 13:45:29 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /opt/conda/lib/python3.7/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 22307 (\N{CJK
# UNIFIED IDEOGRAPH-5723}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# /opt/conda/lib/python3.7/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 22899 (\N{CJK
# UNIFIED IDEOGRAPH-5973}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# /opt/conda/lib/python3.7/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 26524 (\N{CJK
# UNIFIED IDEOGRAPH-679C}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# /opt/conda/lib/python3.7/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# /opt/conda/lib/python3.7/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 22307 (\N{CJK
# UNIFIED IDEOGRAPH-5723}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# /opt/conda/lib/python3.7/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 22899 (\N{CJK
# UNIFIED IDEOGRAPH-5973}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# /opt/conda/lib/python3.7/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 26524 (\N{CJK
# UNIFIED IDEOGRAPH-679C}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# [{'pred_scores': array([6.9670061e-11, 5.3844827e-01, 7.0469902e-12, 1.7270209e-09,
#          1.6581486e-11, 1.9948949e-13, 2.7202438e-15, 2.4308070e-13,
#          7.1182871e-13, 9.4475480e-14, 1.8473921e-09, 4.7533534e-14,
#          8.7043503e-07, 1.2674293e-07, 3.3980461e-07, 1.3354066e-09,
#          1.5294006e-11, 1.2004907e-11, 2.4995943e-08, 2.3404924e-15,
#          3.2570948e-05, 2.5761278e-08, 1.7806107e-11, 4.3500455e-12,
#          6.0099286e-09, 1.5785483e-07, 4.6151772e-01, 1.9465039e-08,
#          1.8953968e-14, 8.5046953e-14], dtype=float32),
#   'pred_label': 1,
#   'pred_score': 0.5384482741355896,
#   'pred_class': '圣女果'}]
